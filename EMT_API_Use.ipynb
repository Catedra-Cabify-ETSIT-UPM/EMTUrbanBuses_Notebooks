# %% [markdown]
# # EMT MADRID - MobilityLabs API
# The docs of the API can be found here:
# https://apidocs.emtmadrid.es/
#
# To start using the API, it is necessary to register an account with an email and a password that allow us to login and get an access token, we can do that in the following website:
# https://mobilitylabs.emtmadrid.es/
#
# We also have access to some examples and the source code of the api in the following link: https://gitlab.com/mobilitylabsmadrid
#
# The following notebook gives a simple idea of how to use the main methods of the API, but there are more available that can be found in the docs.

# %%
#First we import the requested modules
import pandas as pd #Module for the dataframes
import geopandas as gpd #For the geodataframes
import requests 
import json
from shapely.geometry import Point, LineString
from shapely.geometry import shape
from shapely import wkt
import fiona
import asyncio
from concurrent.futures import ThreadPoolExecutor
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

#We use this to plot the graphics below the line when calling plot()
# %matplotlib inline

#Function to ensure we get a good response for the request
def requests_retry_session(retries=3,backoff_factor=0.3,status_forcelist=(500, 502, 504),session=None):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

# %% [markdown]
# ## Start session in the API
# Once we have our account, we can login and get an accessToken with the following method:

# %%
#Our access credentials
email = 'p.parker230220@gmail.com'
password = 'CkBLZvmg5Jg&pej64$'
email = 'alejarabo@gmail.com'
password = 'YXKE8fDrX.pMZ58'

#We make the request for the login, in order to get the access token
response = requests_retry_session().get(
    'https://openapi.emtmadrid.es/v2/mobilitylabs/user/login/',
    headers={
        'email':email,
        'password':password
    },
    timeout=5
)

#We transform the response to json
json_response = response.json()
json_response
# Out:
# {'code': '01',
#  'description': 'Token aedb6f3f-b414-4cf0-bfac-d686aa0d8c71 extend  into control-cache',
#  'datetime': '2020-03-19T12:22:11.973146',
#  'data': [{'nameApp': 'OPENAPI MobilityLabs',
#    'updatedAt': '2020-02-24T08:40:49.7200000',
#    'userName': 'alejarabo',
#    'lastUpdate': {'$date': 1584616862345},
#    'idUser': '9e44cabc-d4bd-4cc7-bbc4-89ae4f8adaf5',
#    'priv': 'U',
#    'tokenSecExpiration': 86399,
#    'email': 'alejarabo@gmail.com',
#    'tokenDteExpiration': {'$date': 1584706861345},
#    'flagAdvise': True,
#    'accessToken': 'aedb6f3f-b414-4cf0-bfac-d686aa0d8c71',
#    'apiCounter': {'current': 3,
#     'dailyUse': 20000,
#     'owner': 0,
#     'licenceUse': 'Please mention EMT Madrid MobilityLabs as data source. Thank you and enjoy!',
#     'aboutUses': 'If you need to extend the daily use of this API, please, register your App in Mobilitylabs and use your own X-ClientId and  passKey instead of generic login (more info in https://mobilitylabs.emtmadrid.es/doc/new-app and https://apidocs.emtmadrid.es/#api-Block_1_User_identity-login)'},
#    'username': 'alejarabo'}]}

# %%
#We get the access token from the json and print it
accessToken = json_response['data'][0]['accessToken']
accessToken
# Out:
# 'aedb6f3f-b414-4cf0-bfac-d686aa0d8c71'

# %% [markdown]
# ## Get the stops that belong to a line and a direction
# Calling the following method we get the stops that a bus passes through when it goes through the specified line and direction

# %%
lineId = '1' #We want to get the stops for the line with id=1
direction = '1' #In the direction 1
response = requests_retry_session().get(
    'https://openapi.emtmadrid.es/v2/transport/busemtmad/lines/{}/stops/{}/'.format(lineId,direction),
    headers = {'accessToken': accessToken}
)

#We turn the response into a json and show the result of the request
line_stops = response.json()['data'][0]
line_stops
# Out:
# {'line': '001',
#  'label': '1',
#  'stops': [{'stop': '4514',
#    'name': 'Cristo Rey',
#    'postalAddress': 'Isaac Peral, frente al Nº 40.',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71793052606063, 40.4384746558032]},
#    'pmv': '61748',
#    'dataLine': ['001', '044', '069', '082', '132']},
#   {'stop': '4022',
#    'name': 'Junta Municipal Moncloa',
#    'postalAddress': 'Isaac Peral frente al Nº 8',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71842134613126, 40.4358409821157]},
#    'pmv': '61745',
#    'dataLine': ['001', '044', '062', '069', '082', '132', '138', '521']},
#   {'stop': '3687',
#    'name': 'Moncloa',
#    'postalAddress': 'Arcipreste de Hita con C/ Fernando el Catolico',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.7180849386363, 40.4341403665582]},
#    'pmv': '61225',
#    'dataLine': ['001', '044', '062', '069', '138', '521']},
#   {'stop': '737',
#    'name': 'Altamirano',
#    'postalAddress': 'Princesa, 75',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71755743564742, 40.4322066996085]},
#    'pmv': '61113',
#    'dataLine': ['001', '044', '069', '133', '138', '521']},
#   {'stop': '735',
#    'name': 'Argüelles',
#    'postalAddress': 'Princesa, 47 ( Alberto Aguilera )',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71607373122696, 40.4301528207731]},
#    'pmv': '61180',
#    'dataLine': ['001', '044', '069', '133', '138', '521']},
#   {'stop': '193',
#    'name': 'Princesa-Rey Francisco',
#    'postalAddress': 'Princesa, 29 (Evaristo San Miguel )',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71453003324472, 40.4279911839452]},
#    'pmv': '61179',
#    'dataLine': ['001', '002', '044', '069', '133', '138']},
#   {'stop': '173',
#    'name': 'Ventura Rodríguez',
#    'postalAddress': 'Princesa, 15-17 (Ventura Rodríguez)',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71313036134631, 40.4260628731286]},
#    'pmv': '61177',
#    'dataLine': ['001',
#     '002',
#     '044',
#     '062',
#     '069',
#     '074',
#     '133',
#     '138',
#     '521']},
#   {'stop': '171',
#    'name': 'Gran Vía-Plaza de España',
#    'postalAddress': 'Gran Vía, 71',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71051696529709, 40.4230519060504]},
#    'pmv': '61135',
#    'dataLine': ['001', '002', '046', '074', '518', '519', '520', '521']},
#   {'stop': '169',
#    'name': 'Santo Domingo',
#    'postalAddress': 'Gran Vía, 47',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.70745560004835, 40.4211427174884]},
#    'pmv': '61351',
#    'dataLine': ['001',
#     '002',
#     '046',
#     '074',
#     '146',
#     '518',
#     '519',
#     '520',
#     '521']},
#   {'stop': '723',
#    'name': 'Gran Vía-Callao',
#    'postalAddress': 'Gran Vía, 33',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.70429255297588, 40.4201710049336]},
#    'pmv': '61783',
#    'dataLine': ['001',
#     '002',
#     '046',
#     '074',
#     '146',
#     '518',
#     '519',
#     '520',
#     '521']},
#   {'stop': '724',
#    'name': 'Gran Vía-Montera',
#    'postalAddress': 'Gran Vía, 21',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.70108154783931, 40.4200013000184]},
#    'pmv': '61587',
#    'dataLine': ['001',
#     '002',
#     '046',
#     '074',
#     '146',
#     '518',
#     '519',
#     '520',
#     '521']},
#   {'stop': '5138',
#    'name': 'Gran Vía-Pedro Zerolo',
#    'postalAddress': 'Gran Vía, 11',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.69935321863076, 40.4196153531909]},
#    'pmv': '61150',
#    'dataLine': ['001',
#     '002',
#     '046',
#     '074',
#     '146',
#     '518',
#     '519',
#     '520',
#     '521',
#     '602']},
#   {'stop': '164',
#    'name': 'Círculo de Bellas Artes',
#    'postalAddress': 'Gran Vía  con C/ Alcalá',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.69714696173351, 40.4189619874668]},
#    'pmv': None,
#    'dataLine': ['001', '002', '046', '074', '146', '602']},
#   {'stop': '70',
#    'name': 'Cibeles',
#    'postalAddress': 'Pza. de Cibeles con Pº del Prado',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.69337395070087, 40.4191558117028]},
#    'pmv': '61292',
#    'dataLine': ['001',
#     '002',
#     '009',
#     '015',
#     '020',
#     '051',
#     '052',
#     '074',
#     '146',
#     '505',
#     '506',
#     '507']},
#   {'stop': '162',
#    'name': 'Retiro',
#    'postalAddress': 'Pza. de la Independencia (Retiro)',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.68826031065316, 40.4196998317684]},
#    'pmv': '61329',
#    'dataLine': ['001',
#     '002',
#     '009',
#     '015',
#     '019',
#     '020',
#     '051',
#     '052',
#     '074',
#     '146',
#     '502',
#     '503',
#     '505',
#     '506',
#     '507',
#     '508']},
#   {'stop': '423',
#    'name': 'Velázquez-Villanueva',
#    'postalAddress': 'Velázquez, 8',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.6842085978824, 40.4222103360285]},
#    'pmv': '61122',
#    'dataLine': ['001', '009', '019', '051', '074']},
#   {'stop': '424',
#    'name': 'Velázquez-Goya',
#    'postalAddress': 'Velázquez, 30',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.68402393107085, 40.4249321557231]},
#    'pmv': '61243',
#    'dataLine': ['001', '009', '019', '051', '074', '504']},
#   {'stop': '425',
#    'name': 'Velázquez-Ayala',
#    'postalAddress': 'Velazquez, 54',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.68379209699484, 40.4276542524136]},
#    'pmv': '61127',
#    'dataLine': ['001', '009', '019', '051', '074']},
#   {'stop': '426',
#    'name': 'Velázquez-Ortega y Gasset',
#    'postalAddress': 'Velázquez, 82',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.68351054073109, 40.4301243881932]},
#    'pmv': '61128',
#    'dataLine': ['001', '009', '019', '051', '074', '504']},
#   {'stop': '731',
#    'name': 'Marqués de Salamanca',
#    'postalAddress': 'José Ortega y Gasset, 34',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.68061037736158, 40.4301324609252]},
#    'pmv': None,
#    'dataLine': ['001', '074']},
#   {'stop': '729',
#    'name': 'Lista',
#    'postalAddress': 'José Ortega y Gasset, 60',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67596319999836, 40.4299254459472]},
#    'pmv': None,
#    'dataLine': ['001', '074']},
#   {'stop': '727',
#    'name': 'Parque Eva Duarte',
#    'postalAddress': 'José Ortega y Gasset, 100',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67088111068427, 40.4296982417158]},
#    'pmv': None,
#    'dataLine': ['001', '074']},
#   {'stop': '726',
#    'name': 'Cartagena-Francisco Silvela',
#    'postalAddress': 'Cartagena, 6',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67045769253278, 40.4311376340219]},
#    'pmv': None,
#    'dataLine': ['001', '043', '074']},
#   {'stop': '2304',
#    'name': 'Plaza San Cayetano',
#    'postalAddress': 'Pza. de San Cayetano con C/ Eraso',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67023163224383, 40.4344993091192]},
#    'pmv': None,
#    'dataLine': ['001']},
#   {'stop': '721',
#    'name': 'Cartagena-Béjar',
#    'postalAddress': 'Cartagena, 64',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67095529120928, 40.4373239510092]},
#    'pmv': None,
#    'dataLine': ['001']},
#   {'stop': '717',
#    'name': 'Cartagena',
#    'postalAddress': 'Cartagena, 106',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67363149950633, 40.4396958031539]},
#    'pmv': None,
#    'dataLine': ['001', '072']},
#   {'stop': '715',
#    'name': 'Cartagena-López de Hoyos',
#    'postalAddress': 'Cartagena, 140',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67554761839799, 40.4426125692938]},
#    'pmv': None,
#    'dataLine': ['001']},
#   {'stop': '745',
#    'name': 'Auditorio Nacional',
#    'postalAddress': 'Suero de Quiñones, 13',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67636141709255, 40.4449861965628]},
#    'pmv': None,
#    'dataLine': ['001']},
#   {'stop': '273',
#    'name': 'Prosperidad',
#    'postalAddress': 'López de Hoyos, 73.',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.67489619473516, 40.4438010524072]},
#    'pmv': '61563',
#    'dataLine': ['001']}],
#  'timeTable': [{'IdLine': '001',
#    'Label': '1',
#    'nameA': 'PLAZA DE CRISTO REY',
#    'nameB': 'PROSPERIDAD',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:15',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '38',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:45',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '38',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:15',
#       'MinimunFrequency': '11',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:35',
#       'StopTime': '23:45',
#       'MinimunFrequency': '11',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:15',
#       'MinimunFrequency': '14',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:35',
#       'StopTime': '23:45',
#       'MinimunFrequency': '14',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '044',
#    'Label': '44',
#    'nameA': 'PLAZA DEL CALLAO',
#    'nameB': 'MARQUES DE VIANA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:04',
#       'MinimunFrequency': '12',
#       'MaximumFrequency': '22',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '12',
#       'MaximumFrequency': '22',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:45',
#       'StopTime': '23:04',
#       'MinimunFrequency': '8',
#       'MaximumFrequency': '18',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '8',
#       'MaximumFrequency': '18',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:45',
#       'StopTime': '23:04',
#       'MinimunFrequency': '11',
#       'MaximumFrequency': '21',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '11',
#       'MaximumFrequency': '21',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '069',
#    'Label': 'C2',
#    'nameA': 'CIRCULAR 2',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:00',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '4',
#       'MaximumFrequency': '12',
#       'Frequency': None},
#      'Direction2': {'StartTime': '05:25',
#       'StopTime': '23:00',
#       'MinimunFrequency': '4',
#       'MaximumFrequency': '12',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '05:25',
#       'StopTime': '23:00',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '082',
#    'Label': '82',
#    'nameA': 'MONCLOA',
#    'nameB': 'PITIS',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '19',
#       'MaximumFrequency': '31',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '19',
#       'MaximumFrequency': '31',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '18',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '18',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '33',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '33',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '132',
#    'Label': '132',
#    'nameA': 'MONCLOA',
#    'nameB': 'HOSPITAL LA PAZ',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '22:55',
#       'MinimunFrequency': '18',
#       'MaximumFrequency': '36',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '18',
#       'MaximumFrequency': '36',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '22:55',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '17',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:35',
#       'StopTime': '23:30',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '17',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '22:55',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:35',
#       'StopTime': '23:30',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '062',
#    'Label': '62',
#    'nameA': 'PLAZA DE CRISTO REY',
#    'nameB': 'LOS PUERTOS',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:20',
#       'MinimunFrequency': '17',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '17',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:40',
#       'StopTime': '23:20',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '27',
#       'Frequency': None},
#      'Direction2': {'StartTime': '05:50',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '27',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:40',
#       'StopTime': '23:20',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'Direction2': {'StartTime': '05:50',
#       'StopTime': '23:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '138',
#    'Label': '138',
#    'nameA': 'PLAZA DE CRISTO REY',
#    'nameB': 'COLONIA SAN IGNACIO DE LOYOLA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:15',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:30',
#       'StopTime': '23:15',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:30',
#       'StopTime': '23:15',
#       'MinimunFrequency': '12',
#       'MaximumFrequency': '27',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '12',
#       'MaximumFrequency': '27',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '521',
#    'Label': 'N21',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'ARROYO DEL FRESNO',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:20',
#       'StopTime': '05:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:20',
#       'StopTime': '06:15',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '133',
#    'Label': '133',
#    'nameA': 'PLAZA DEL CALLAO',
#    'nameB': 'MIRASIERRA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '22:50',
#       'MinimunFrequency': '11',
#       'MaximumFrequency': '26',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '11',
#       'MaximumFrequency': '26',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '22:50',
#       'MinimunFrequency': '4',
#       'MaximumFrequency': '14',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '4',
#       'MaximumFrequency': '14',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '22:50',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '32',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '32',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '002',
#    'Label': '2',
#    'nameA': 'PLAZA DE MANUEL BECERRA',
#    'nameB': 'AVENIDA REINA VICTORIA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:45',
#       'MinimunFrequency': '12',
#       'MaximumFrequency': '34',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:45',
#       'MinimunFrequency': '12',
#       'MaximumFrequency': '34',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:45',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '15',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:00',
#       'StopTime': '23:45',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '15',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:45',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:00',
#       'StopTime': '23:45',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '074',
#    'Label': '74',
#    'nameA': 'PASEO DEL PINTOR ROSALES',
#    'nameB': 'PARQUE DE LAS AVENIDAS',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:15',
#       'MinimunFrequency': '14',
#       'MaximumFrequency': '31',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:45',
#       'MinimunFrequency': '14',
#       'MaximumFrequency': '31',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '23:15',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:45',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:00',
#       'StopTime': '23:15',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '26',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:45',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '26',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '046',
#    'Label': '46',
#    'nameA': 'SEVILLA',
#    'nameB': 'MONCLOA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '17',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '17',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:05',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '7',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:05',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '518',
#    'Label': 'N18',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'ALUCHE',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:30',
#       'StopTime': '06:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '06:10',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:32',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:32',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '07:40',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '519',
#    'Label': 'N19',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'COLONIA SAN IGNACIO DE LOYOLA',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:30',
#       'StopTime': '06:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '06:10',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:30',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:30',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '07:40',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '520',
#    'Label': 'N20',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'PITIS',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:20',
#       'StopTime': '05:30',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '41'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '41'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:20',
#       'StopTime': '06:09',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '146',
#    'Label': '146',
#    'nameA': 'PLAZA DEL CALLAO',
#    'nameB': 'LOS MOLINOS',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:00',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:55',
#       'StopTime': '23:00',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '16',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '16',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:55',
#       'StopTime': '23:00',
#       'MinimunFrequency': '8',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '8',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '009',
#    'Label': '9',
#    'nameA': 'SEVILLA',
#    'nameB': 'HORTALEZA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '22:55',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:55',
#       'StopTime': '22:55',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:55',
#       'StopTime': '22:55',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '19',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '19',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '015',
#    'Label': '15',
#    'nameA': 'PUERTA DEL SOL/SEVILLA',
#    'nameB': 'LA ELIPA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:02',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '29',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '29',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:32',
#       'StopTime': '23:02',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:32',
#       'StopTime': '23:02',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '21',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '21',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '020',
#    'Label': '20',
#    'nameA': 'PUERTA DEL SOL/SEVILLA',
#    'nameB': 'PAVONES',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:00',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '21',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '21',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:55',
#       'StopTime': '23:00',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '18',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '5',
#       'MaximumFrequency': '18',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:55',
#       'StopTime': '23:00',
#       'MinimunFrequency': '8',
#       'MaximumFrequency': '24',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '8',
#       'MaximumFrequency': '24',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '051',
#    'Label': '51',
#    'nameA': 'PUERTA DEL SOL',
#    'nameB': 'PLAZA DEL PERU',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '28',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '28',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:05',
#       'StopTime': '23:05',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:27',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:05',
#       'StopTime': '23:05',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '26',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:27',
#       'StopTime': '23:30',
#       'MinimunFrequency': '13',
#       'MaximumFrequency': '26',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '052',
#    'Label': '52',
#    'nameA': 'PUERTA DEL SOL/SEVILLA',
#    'nameB': 'SANTAMARCA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:26',
#       'StopTime': '23:05',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '22',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:50',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '22',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:26',
#       'StopTime': '23:05',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:50',
#       'StopTime': '23:30',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '505',
#    'Label': 'N5',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'COLONIA FIN DE SEMANA',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:20',
#       'StopTime': '05:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '35'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:38',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:20',
#       'StopTime': '06:15',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '506',
#    'Label': 'N6',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'LAS ROSAS',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:40',
#       'StopTime': '05:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '40'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '40'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:32',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:40',
#       'StopTime': '06:15',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '507',
#    'Label': 'N7',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'VALDERRIVAS',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:50',
#       'StopTime': '05:30',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '40'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '40'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:50',
#       'StopTime': '06:15',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '019',
#    'Label': '19',
#    'nameA': 'PLAZA DE CATALUÑA',
#    'nameB': 'PLAZA DE LEGAZPI',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:03',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '28',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '28',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:45',
#       'StopTime': '23:03',
#       'MinimunFrequency': '3',
#       'MaximumFrequency': '12',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '3',
#       'MaximumFrequency': '12',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:45',
#       'StopTime': '23:03',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '20',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '502',
#    'Label': 'N2',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'VALDEBEBAS',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:50',
#       'StopTime': '05:30',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '40'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '40'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:50',
#       'StopTime': '06:15',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '503',
#    'Label': 'N3',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'CANILLAS',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:40',
#       'StopTime': '05:35',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '06:28',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:40',
#       'StopTime': '06:15',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '508',
#    'Label': 'N8',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'VALDEBERNARDO',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:40',
#       'StopTime': '05:30',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '40'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '05:50',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '40'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:15',
#       'StopTime': '05:40',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:15',
#       'StopTime': '05:40',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '35',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:40',
#       'StopTime': '06:15',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '40',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '15',
#       'MaximumFrequency': '40',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '504',
#    'Label': 'N4',
#    'nameA': 'PLAZA DE CIBELES',
#    'nameB': 'BARAJAS',
#    'typeOfDays': [{'Direction1': {'StartTime': '23:50',
#       'StopTime': '06:30',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '40'},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '06:08',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '40'},
#      'DayType': 'VI'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '23:30',
#       'StopTime': '05:50',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:55',
#       'StopTime': '05:10',
#       'MinimunFrequency': '35',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '23:50',
#       'StopTime': '06:15',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'Direction2': {'StartTime': '23:45',
#       'StopTime': '07:00',
#       'MinimunFrequency': '20',
#       'MaximumFrequency': '50',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '043',
#    'Label': '43',
#    'nameA': 'AVENIDA DE FELIPE II',
#    'nameB': 'ESTRECHO',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:02',
#       'MinimunFrequency': '19',
#       'MaximumFrequency': '32',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '19',
#       'MaximumFrequency': '32',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:02',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '22',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '10',
#       'MaximumFrequency': '22',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '06:30',
#       'StopTime': '23:02',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:00',
#       'StopTime': '23:30',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'SA'}]},
#   {'IdLine': '072',
#    'Label': '72',
#    'nameA': 'DIEGO DE LEON',
#    'nameB': 'HORTALEZA',
#    'typeOfDays': [{'Direction1': {'StartTime': '07:00',
#       'StopTime': '23:05',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'Direction2': {'StartTime': '07:30',
#       'StopTime': '23:30',
#       'MinimunFrequency': '16',
#       'MaximumFrequency': '25',
#       'Frequency': None},
#      'DayType': 'FE'},
#     {'Direction1': {'StartTime': '05:50',
#       'StopTime': '23:05',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '9',
#       'MaximumFrequency': '23',
#       'Frequency': None},
#      'DayType': 'LA'},
#     {'Direction1': {'StartTime': '05:50',
#       'StopTime': '23:05',
#       'MinimunFrequency': '14',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'Direction2': {'StartTime': '06:15',
#       'StopTime': '23:30',
#       'MinimunFrequency': '14',
#       'MaximumFrequency': '30',
#       'Frequency': None},
#      'DayType': 'SA'}]}]}

# %% [markdown]
# ## Information about buses that are going to arrive a certain stop
# With this method we can get a lot information about the buses that are going to arrive a stop, such as the ETA, the distance, the bus id and much more. We have to send a json in the data of the request to specify if we want to get or not information about the stop, the incidents and the estimations. If we dont specify the line we want to get the information about, it returns us the information about all the lines that pass through this stop.

# %%
#We get the id for the first stop of the line 1
stopId = line_stops['stops'][0]['stop']

#We construct the body for the request
body = {
    'cultureInfo': 'EN',
    'Text_StopRequired_YN': 'Y',
    'Text_EstimationsRequired_YN': 'Y',
    'Text_IncidencesRequired_YN': 'Y',
    'DateTime_Referenced_Incidencies_YYYYMMDD':'20200130'
}

#And we turn it into a json object
body = json.dumps(body)
body
# Out:
# '{"cultureInfo": "EN", "Text_StopRequired_YN": "Y", "Text_EstimationsRequired_YN": "Y", "Text_IncidencesRequired_YN": "Y", "DateTime_Referenced_Incidencies_YYYYMMDD": "20200130"}'

# %%
import re
import datetime
#And once we have all the attributes for the request ready, we perform it like this:
response = requests_retry_session().post(
    'https://openapi.emtmadrid.es/v2/transport/busemtmad/stops/{}/arrives/{}/'.format('162','1'),
    data = body,
    headers = {
        'accessToken': accessToken,
        'Content-Type': 'application/json' #We specify that we are doing an application with a json object
    },
    timeout = 5
)

#And we show the data returned by the request
response.status_code
arrival_data = response.json()
arrival_data['data'][0]
# Out:
# {'Arrive': [{'line': '1',
#    'stop': '162',
#    'isHead': 'False',
#    'destination': 'PROSPERIDAD',
#    'deviation': 0,
#    'bus': 8260,
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.718292731286625, 40.43381472962691]},
#    'estimateArrive': 158,
#    'DistanceBus': 418,
#    'positionTypeBus': '0'},
#   {'line': '1',
#    'stop': '162',
#    'isHead': 'False',
#    'destination': 'PROSPERIDAD',
#    'deviation': 0,
#    'bus': 119,
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.71765821770476, 40.438609782765894]},
#    'estimateArrive': 1146,
#    'DistanceBus': 3264,
#    'positionTypeBus': '0'}],
#  'StopInfo': [{'lines': [{'label': '1',
#      'line': '001',
#      'nameA': 'CRISTO REY',
#      'nameB': 'PROSPERIDAD',
#      'metersFromHeader': 3979,
#      'to': 'B',
#      'color': '0072ce'}],
#    'stopId': '162',
#    'stopName': 'Retiro',
#    'geometry': {'type': 'Point',
#     'coordinates': [-3.68826031065316, 40.4196998317684]},
#    'Direction': 'Pza. de la Independencia (Retiro)                      '}],
#  'ExtraInfo': [],
#  'Incident': {'ListaIncident': {'data': []}}}

# %% [markdown]
# ## Obtain collections of data
# We can also get collections of data from the API, the collections available are shown in the following link:
# https://mobilitylabs.emtmadrid.es/es/portal/collections
#
# In order to get the data of the desired collection, we have to get its collection id from the site above, and then call the following method

# %%
#We request the collection of Madrid Central Area, that has this id
collection_id = 'b94ea072-77ca-433d-adce-b3504f3abd00'

#And we perform the request
response = requests_retry_session().post(
    'https://openapi.emtmadrid.es/v1/mobilitylabs/collection/reactive/{}/1/'.format(collection_id),
    headers = {
        'accessToken': accessToken,
        'Content-Type': 'application/json'
    },
    data = {},
    timeout = 5
)

#We show the result of the request
response.text
# Out:
# '{"code": "90", "description": "Error in API process Expecting value: line 1 column 1 (char 0)", "datetime": "2020-03-19T12:22:18.444560", "data": []}'

# %% [markdown]
# ## Load static dataframes with the lines and the stops
# For interacting with the data we have about the stops and the lines, we have constructed the two dataframes shown below from the information given in the gtfs (an standard for transit datafiles created by Google) of the EMT Madrid for urban buses(M6). This process is shown in this other notebook:
#
# Both of this dataframes have a 'geometry' column, which contains Point objects for the location of the stops, and LineString objects for the lines. The presence of this column is the main difference between geodataframes and dataframes, but both of them have the same methods for interacting with them

# %%
#We load the stop's data
stops = gpd.read_file('M6/stops.json')
#With head() we show the first five columns of the dataframe
stops.head()
# Out:
#    stop_code                stop_name                    stop_desc zone_id  \
# 0        161         Puerta de Alcalá  Plaza de la Independencia 3       A
# 1        162                   Retiro            Avda de Méjico SN       A
# 2        164  Círculo de Bellas Artes           Calle   Gran Vía 3       A
# 3        168            Santo Domingo           Calle  Gran Vía 56       A
# 4        169            Santo Domingo           Calle  Gran Vía 47       A
#
#    location_type parent_station  wheelchair_boarding  \
# 0              0           None                    2
# 1              0           None                    2
# 2              0           None                    2
# 3              0           None                    2
# 4              0           None                    2
#
#                     geometry
# 0  POINT (-3.68919 40.42069)
# 1  POINT (-3.68826 40.41970)
# 2  POINT (-3.69715 40.41896)
# 3  POINT (-3.70761 40.42159)
# 4  POINT (-3.70746 40.42114)

# %%
#And we load the line's data
route_lines = gpd.read_file('M6Data/route_lines.json')
route_lines.head()
# Out:
#          itinerary_id line_id direction  orig_dist    dist  \
# 0  6_N_501____1__IT_1     501         1     84.910  20.429
# 1  6_N_501____2__IT_1     501         2     42.932  13.472
# 2  6_N_502____1__IT_1     502         1     60.927  19.403
# 3  6_N_502____2__IT_1     502         2     96.684  21.195
# 4  6_N_503____1__IT_1     503         1     31.595  14.011
#
#                                             geometry
# 0  LINESTRING (-3.69234 40.41997, -3.69193 40.420...
# 1  LINESTRING (-3.64667 40.48592, -3.64668 40.485...
# 2  LINESTRING (-3.69269 40.41872, -3.69269 40.418...
# 3  LINESTRING (-3.61127 40.49814, -3.61091 40.498...
# 4  LINESTRING (-3.69269 40.41872, -3.69269 40.418...

# %% [markdown]
# ## Get point that is at a certain distance on a LineString from a given point
# When we call the method for the information about a stop, it returns us the distance of this buses to the stop, but not the coordinates of them (it returns [0,0]). This method transforms the distance of the bus to the stop into the coordinates that correspond to going back along the line 'distance' meters.

# %%
def point_by_distance_on_line (line, line_lenght, distance, origin_point) :
    """
    Returns the coordinates of the bus location

        Parameters
        ----------
        line : LineString
            The line that the bus belongs to
        line_length : float
            The length of the line
        distance : float
            The distance of the bus to the stop in kilometers
        origin_point : Point
            The location of the bus stop
    """
    
    #First we calculate the normalized distance of the bus from the start of the line
    #by substracting the distance of the bus to the stop to the distance of the stop to the start of the line
    #which is returned by the project method of the shapely module
    normalized_distance = line.project(origin_point,normalized=True) - distance/line_lenght
    
    #Then we get the the coordinates of the point that is at the normalized distance obtained 
    #before from the start of the line with the interpolate method
    interpolated_point = line.interpolate(normalized_distance,normalized=True)
    
    #And we return the coordinates of the point
    return (interpolated_point.x,interpolated_point.y)

# %% [markdown]
# ## Create dictionary with stops for each line and direction
# In order to make some methods faster, we build a dictionary that contains the stop codes and locations in an array for each line and direction.

# %%
def get_stops_of_line(lineId,direction,accessToken) :
    """
    Returns the list of stops for the line and direction desired

        Parameters
        ----------
        lineId : string
            The line id
        direction : string
            The direction (1 or 2)
        accessToken: string
            The accessToken obtained in the login
    """
    
    response = requests_retry_session().get(
        'https://openapi.emtmadrid.es/v2/transport/busemtmad/lines/{}/stops/{}/'.format(lineId,direction),
        headers = {'accessToken': accessToken},
        timeout = 5
    )
    
    #We turn the data of the stops from the response into a dataframe
    stops_data = pd.DataFrame(response.json()['data'][0]['stops'])   
    #And transform the geometry coordinates into point objects
    stops_data['geometry'] = [shape(i) for i in stops_data['geometry']]
    return stops_data

#We construct the dictionary
with open('M6Data/line_stops_dict.json', 'r') as f:
    line_stops_dict = json.load(f)
line_stops_dict = {}
#If we want to build the dictionary for all the stops we uncomment this (takes about 45min):
#line_ids = route_lines['line_id'].unique() 
#In order to make the example faster we just get the data for two lines
line_ids = ['1','2']
for lineId in line_ids:   
    if lineId not in line_stops_dict :
        line_stops_dict[lineId] = {}
    for direction in route_lines['direction'].unique(): 
        #For each line and direction we get the stops data and put it inside the dict
        try:
            if direction not in line_stops_dict[lineId] :
                line_stops_dict[lineId][direction] = {}
            if 'stops' in line_stops_dict[lineId][direction] :
                pass
            else :
                stops_data = get_stops_of_line(lineId,direction,accessToken)
                line_stops_dict[lineId][direction] = {
                    'stops' : stops_data['stop'].tolist()
                }     
        except :
            pass

#We save the new dict
with open('M6Data/line_stops_dict.json', 'w') as fp:
    json.dump(line_stops_dict, fp)

# %%
line_stops_dict.keys()
# Out:
# dict_keys(['1', '2'])
